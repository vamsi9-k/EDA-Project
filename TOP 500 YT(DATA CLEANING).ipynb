# %%
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("TOP 500 Youtubers.csv")

# %%
df
# Out:
#                         Youtuber  Subscribers      Video views  \
# 0                        MrBeast  384,000,000   78,500,765,091
# 1                       T-Series  292,000,000  293,662,998,286
# 2     Cocomelon - Nursery Rhymes  192,000,000  199,814,715,419
# 3                 YouTube Movies  188,000,000                0
# 4                      SET India  183,000,000  176,535,278,856
# ...                          ...          ...              ...
# 1015               Lance Pugmire          337          786,229
# 1016              vitaminwatermx          711          652,261
# 1017                    Kim Dave      491,000       34,307,156
# 1018         Arte da BÃª AteliÃª      469,000       41,911,075
# 1019            sophia rodrigues       37,500        2,518,780
#
#       Total Video count                             Country       Category  \
# 0                   859   United States (US)                 Entertainment
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 11 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Youtuber                            1020 non-null   object
#  1   Subscribers                         1020 non-null   object
#  2   Video views                         1020 non-null   object
#  3   Total Video count                   1020 non-null   int64
#  4   Country                             1004 non-null   object
#  5   Category                            1020 non-null   object
#  6   Youtuber since                      1020 non-null   int64
#  7   Last 7 Days Subscribers             1020 non-null   object
#  8   Last 30 Days Subscribers            1020 non-null   object
#  9   Last 90 Days Subscribers            1020 non-null   object
#  10  Estimated earnings in past 30 days  1002 non-null   object
# dtypes: int64(2), object(9)
# ...

# %%
df.duplicated().sum()
# Out:
# 509

# %%
df=df.drop_duplicates()

# %%
df
# Out:
#                         Youtuber  Subscribers      Video views  \
# 0                        MrBeast  384,000,000   78,500,765,091
# 1                       T-Series  292,000,000  293,662,998,286
# 2     Cocomelon - Nursery Rhymes  192,000,000  199,814,715,419
# 3                 YouTube Movies  188,000,000                0
# 4                      SET India  183,000,000  176,535,278,856
# ...                          ...          ...              ...
# 1005               Lance Pugmire          337          786,229
# 1006              vitaminwatermx          711          652,261
# 1007                    Kim Dave      491,000       34,307,156
# 1008         Arte da BÃª AteliÃª      469,000       41,911,075
# 1009            sophia rodrigues       37,500        2,518,780
#
#       Total Video count                             Country       Category  \
# 0                   859   United States (US)                 Entertainment
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 511 entries, 0 to 1009
# Data columns (total 11 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Youtuber                            511 non-null    object
#  1   Subscribers                         511 non-null    object
#  2   Video views                         511 non-null    object
#  3   Total Video count                   511 non-null    int64
#  4   Country                             503 non-null    object
#  5   Category                            511 non-null    object
#  6   Youtuber since                      511 non-null    int64
#  7   Last 7 Days Subscribers             511 non-null    object
#  8   Last 30 Days Subscribers            511 non-null    object
#  9   Last 90 Days Subscribers            511 non-null    object
#  10  Estimated earnings in past 30 days  502 non-null    object
# dtypes: int64(2), object(9)
# ...

# %%
df
# Out:
#                         Youtuber  Subscribers      Video views  \
# 0                        MrBeast  384,000,000   78,500,765,091
# 1                       T-Series  292,000,000  293,662,998,286
# 2     Cocomelon - Nursery Rhymes  192,000,000  199,814,715,419
# 3                 YouTube Movies  188,000,000                0
# 4                      SET India  183,000,000  176,535,278,856
# ...                          ...          ...              ...
# 1005               Lance Pugmire          337          786,229
# 1006              vitaminwatermx          711          652,261
# 1007                    Kim Dave      491,000       34,307,156
# 1008         Arte da BÃª AteliÃª      469,000       41,911,075
# 1009            sophia rodrigues       37,500        2,518,780
#
#       Total Video count                             Country       Category  \
# 0                   859   United States (US)                 Entertainment
# ...

# %%
df[["Last 7 Days Subscribers","Last 7 Days Video views"]]=df["Last 7 Days Subscribers"].str.split(" ",expand=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6960\1667637884.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[["Last 7 Days Subscribers","Last 7 Days Video views"]]=df["Last 7 Days Subscribers"].str.split(" ",expand=True)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6960\1667637884.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[["Last 7 Days Subscribers","Last 7 Days Video views"]]=df["Last 7 Days Subscribers"].str.split(" ",expand=True)

# %%
df[["Last 30 Days Subscribers","Last 30 Days Video views"]]=df["Last 30 Days Subscribers"].str.split(" ",expand=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6960\1351600018.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[["Last 30 Days Subscribers","Last 30 Days Video views"]]=df["Last 30 Days Subscribers"].str.split(" ",expand=True)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6960\1351600018.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[["Last 30 Days Subscribers","Last 30 Days Video views"]]=df["Last 30 Days Subscribers"].str.split(" ",expand=True)

# %%
df[["Last 90 Days Subscribers","Last 90 Days Video views"]]=df["Last 90 Days Subscribers"].str.split(" ",expand=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6960\1609299000.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[["Last 90 Days Subscribers","Last 90 Days Video views"]]=df["Last 90 Days Subscribers"].str.split(" ",expand=True)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6960\1609299000.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[["Last 90 Days Subscribers","Last 90 Days Video views"]]=df["Last 90 Days Subscribers"].str.split(" ",expand=True)

# %%
df.columns
# Out:
# Index(['Youtuber', 'Subscribers', 'Video views', 'Total Video count',
#        'Country', 'Category', 'Youtuber since', 'Last 7 Days Subscribers',
#        'Last 30 Days Subscribers', 'Last 90 Days Subscribers',
#        'Estimated earnings in past 30 days', 'Last 7 Days Video views',
#        'Last 30 Days Video views', 'Last 90 Days Video views'],
#       dtype='object')

# %%
l=["Last 7 Days Subscribers","Last 30 Days Subscribers","Last 90 Days Subscribers"]
for i in l:
    df[i]=df[i].str.replace("[","")
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6960\3287759794.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[i]=df[i].str.replace("[","")

# %%
l=["Last 7 Days Subscribers","Last 30 Days Subscribers","Last 90 Days Subscribers"]
for i in l:
    df[i]=df[i].str.replace(",","")
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6960\2371874212.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[i]=df[i].str.replace(",","")

# %%
l=["Last 7 Days Video views","Last 30 Days Video views","Last 90 Days Video views"]
for i in l:
    df[i]=df[i].str.replace(",","")
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6960\3873912149.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[i]=df[i].str.replace(",","")

# %%
l=["Last 7 Days Video views","Last 30 Days Video views","Last 90 Days Video views"]
for i in l:
    df[i]=df[i].str.replace("]","")
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6960\674244912.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[i]=df[i].str.replace("]","")

# %%
l=["Last 7 Days Video views","Last 30 Days Video views","Last 90 Days Video views","Last 7 Days Subscribers","Last 30 Days Subscribers","Last 90 Days Subscribers"]
for i in l:
    df[i]=df[i].str.removeprefix("'")
    df[i]=df[i].str.removesuffix("'")
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6960\2322009692.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[i]=df[i].str.removeprefix("'")
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6960\2322009692.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[i]=df[i].str.removesuffix("'")

# %%
l=["Subscribers","Video views"]
for i in l:
    df[i]=df[i].str.replace(",","")
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6960\3947647.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[i]=df[i].str.replace(",","")

# %%
df
# Out:
#                         Youtuber Subscribers   Video views  Total Video count  \
# 0                        MrBeast   384000000   78500765091                859
# 1                       T-Series   292000000  293662998286              23239
# 2     Cocomelon - Nursery Rhymes   192000000  199814715419               1504
# 3                 YouTube Movies   188000000             0                  0
# 4                      SET India   183000000  176535278856             153867
# ...                          ...         ...           ...                ...
# 1005               Lance Pugmire         337        786229                177
# 1006              vitaminwatermx         711        652261                 39
# 1007                    Kim Dave      491000      34307156                652
# 1008         Arte da BÃª AteliÃª      469000      41911075                518
# 1009            sophia rodrigues       37500       2518780                181
#
# ...

# %%
df[df["Country"].isna()]
# Out:
#                                         Youtuber Subscribers  Video views  \
# 14                               ê¹íë¡KIMPRO   101000000  68126264450
# 138                                    TheDonato    42500000   8214581475
# 245                                         YOLO    32800000   2618067642
# 269  Boram Tube Vlog [ë³´ëíë¸ ë¸ì´ë¡ê·¸]    31700000  14098311681
# 282                            JYP Entertainment    30400000  24398191276
# 392                        1MILLION Dance Studio    26400000   8515858600
# 424                                 CRAZY GREAPA    25200000  21682779380
# 439                                         GH'S    24600000  19551134694
#
#      Total Video count Country       Category  Youtuber since  \
# 14                3125     NaN         People            2017
# 138               3806     NaN  Entertainment            2015
# 245                394     NaN         Comedy            2015
# ...

# %%
#Korea, Republic of (KR)
df["Country"]=df["Country"].fillna("Korea, Republic of (KR)")
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6960\276827290.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Country"]=df["Country"].fillna("Korea, Republic of (KR)")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 511 entries, 0 to 1009
# Data columns (total 14 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Youtuber                            511 non-null    object
#  1   Subscribers                         511 non-null    object
#  2   Video views                         511 non-null    object
#  3   Total Video count                   511 non-null    int64
#  4   Country                             511 non-null    object
#  5   Category                            511 non-null    object
#  6   Youtuber since                      511 non-null    int64
#  7   Last 7 Days Subscribers             511 non-null    object
#  8   Last 30 Days Subscribers            511 non-null    object
#  9   Last 90 Days Subscribers            511 non-null    object
#  10  Estimated earnings in past 30 days  502 non-null    object
# ...

# %%
df[df["Estimated earnings in past 30 days"].isna()]
# Out:
#                                    Youtuber Subscribers  Video views  \
# 63                                Mikecrack    56100000  20039361921
# 171                       Jkk Entertainment    38500000  17332408833
# 174                             GMA Network    38300000  33407254142
# 218                            SSSniperWolf    34900000  25932913011
# 300  Bebefinn - Nursery Rhymes & Kids Songs    29700000            0
# 359                             Nicki Minaj    27500000  11909881286
# 365                              Pawan Sahu    27200000  12396477595
# 431                                 SSundee    24800000  16166284774
# 452                         Jomy Production    24300000   4281424845
#
#      Total Video count                             Country       Category  \
# 63                2107           Spain (ES)                        Gaming
# 171                248           India (IN)                        Comedy
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 511 entries, 0 to 1009
# Data columns (total 14 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Youtuber                            511 non-null    object
#  1   Subscribers                         511 non-null    object
#  2   Video views                         511 non-null    object
#  3   Total Video count                   511 non-null    int64
#  4   Country                             511 non-null    object
#  5   Category                            511 non-null    object
#  6   Youtuber since                      511 non-null    int64
#  7   Last 7 Days Subscribers             511 non-null    object
#  8   Last 30 Days Subscribers            511 non-null    object
#  9   Last 90 Days Subscribers            511 non-null    object
#  10  Estimated earnings in past 30 days  502 non-null    object
# ...

# %%
# 1,000,000 - 1 million
#  1,000 -  1 thousand

# %%
df=df.dropna()

# %%
df
# Out:
#                         Youtuber Subscribers   Video views  Total Video count  \
# 0                        MrBeast   384000000   78500765091                859
# 1                       T-Series   292000000  293662998286              23239
# 2     Cocomelon - Nursery Rhymes   192000000  199814715419               1504
# 3                 YouTube Movies   188000000             0                  0
# 4                      SET India   183000000  176535278856             153867
# ...                          ...         ...           ...                ...
# 1005               Lance Pugmire         337        786229                177
# 1006              vitaminwatermx         711        652261                 39
# 1007                    Kim Dave      491000      34307156                652
# 1008         Arte da BÃª AteliÃª      469000      41911075                518
# 1009            sophia rodrigues       37500       2518780                181
#
# ...

# %%
df["Estimated earnings in past 30 days"]=df["Estimated earnings in past 30 days"].str.replace("K","000")
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6960\1741282138.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Estimated earnings in past 30 days"]=df["Estimated earnings in past 30 days"].str.replace("K","000")

# %%
df["Estimated earnings in past 30 days"]=df["Estimated earnings in past 30 days"].str.replace("M","000000")
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6960\2347963406.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Estimated earnings in past 30 days"]=df["Estimated earnings in past 30 days"].str.replace("M","000000")

# %%
df["Estimated earnings in past 30 days"]=df["Estimated earnings in past 30 days"].str.replace(".","")
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6960\729814634.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Estimated earnings in past 30 days"]=df["Estimated earnings in past 30 days"].str.replace(".","")

# %%
df["Estimated earnings in past 30 days"]=df["Estimated earnings in past 30 days"].str.replace("$","")
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6960\3906098433.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Estimated earnings in past 30 days"]=df["Estimated earnings in past 30 days"].str.replace("$","")

# %%
df[["Estimated earnings in past 30 days","Estimated  max earnings in past 30 days"]]=df["Estimated earnings in past 30 days"].str.split("-",expand=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6960\2392703999.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[["Estimated earnings in past 30 days","Estimated  max earnings in past 30 days"]]=df["Estimated earnings in past 30 days"].str.split("-",expand=True)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6960\2392703999.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df
# Out:
#                         Youtuber Subscribers   Video views  Total Video count  \
# 0                        MrBeast   384000000   78500765091                859
# 1                       T-Series   292000000  293662998286              23239
# 2     Cocomelon - Nursery Rhymes   192000000  199814715419               1504
# 3                 YouTube Movies   188000000             0                  0
# 4                      SET India   183000000  176535278856             153867
# ...                          ...         ...           ...                ...
# 1005               Lance Pugmire         337        786229                177
# 1006              vitaminwatermx         711        652261                 39
# 1007                    Kim Dave      491000      34307156                652
# 1008         Arte da BÃª AteliÃª      469000      41911075                518
# 1009            sophia rodrigues       37500       2518780                181
#
# ...

# %%
df.columns
# Out:
# Index(['Youtuber', 'Subscribers', 'Video views', 'Total Video count',
#        'Country', 'Category', 'Youtuber since', 'Last 7 Days Subscribers',
#        'Last 30 Days Subscribers', 'Last 90 Days Subscribers',
#        'Estimated earnings in past 30 days', 'Last 7 Days Video views',
#        'Last 30 Days Video views', 'Last 90 Days Video views',
#        'Estimated  max earnings in past 30 days'],
#       dtype='object')

# %%
df["Estimated  max earnings in past 30 days"]
# Out:
# 0         449000000
# 1         463000000
# 2         335000000
# 3                 0
# 4         101000000
#            ...
# 1005              0
# 1006              0
# 1007            209
# 1008            209
# 1009              2
# Name: Estimated  max earnings in past 30 days, Length: 502, dtype: object

# %%
a=["Estimated earnings in past 30 days","Estimated  max earnings in past 30 days"]
for i in a:
    df[i]=df[i].astype("int")
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6960\450247245.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[i]=df[i].astype("int")
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6960\450247245.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[i]=df[i].astype("int")

# %%
df["Country"]=df["Country"].replace(" ","others")
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6960\4211073908.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Country"]=df["Country"].replace(" ","others")

# %%
df["Country"]=df["Country"].str.strip()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6960\2605293324.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Country"]=df["Country"].str.strip()

# %%
df
# Out:
#                         Youtuber Subscribers   Video views  Total Video count  \
# 0                        MrBeast   384000000   78500765091                859
# 1                       T-Series   292000000  293662998286              23239
# 2     Cocomelon - Nursery Rhymes   192000000  199814715419               1504
# 3                 YouTube Movies   188000000             0                  0
# 4                      SET India   183000000  176535278856             153867
# ...                          ...         ...           ...                ...
# 1005               Lance Pugmire         337        786229                177
# 1006              vitaminwatermx         711        652261                 39
# 1007                    Kim Dave      491000      34307156                652
# 1008         Arte da BÃª AteliÃª      469000      41911075                518
# 1009            sophia rodrigues       37500       2518780                181
#
# ...

# %%
a=["Subscribers","Video views","Last 7 Days Subscribers","Last 7 Days Video views","Last 30 Days Subscribers","Last 30 Days Video views","Last 90 Days Subscribers",
     "Last 90 Days Video views"]
for j in a:
    df[j]=df[j].astype("int64")
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6960\1427449178.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[j]=df[j].astype("int64")
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6960\1427449178.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[j]=df[j].astype("int64")
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6960\1427449178.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df
# Out:
#                         Youtuber  Subscribers   Video views  \
# 0                        MrBeast    384000000   78500765091
# 1                       T-Series    292000000  293662998286
# 2     Cocomelon - Nursery Rhymes    192000000  199814715419
# 3                 YouTube Movies    188000000             0
# 4                      SET India    183000000  176535278856
# ...                          ...          ...           ...
# 1005               Lance Pugmire          337        786229
# 1006              vitaminwatermx          711        652261
# 1007                    Kim Dave       491000      34307156
# 1008         Arte da BÃª AteliÃª       469000      41911075
# 1009            sophia rodrigues        37500       2518780
#
#       Total Video count              Country       Category  Youtuber since  \
# 0                   859   United States (US)  Entertainment            2012
# 1                 23239           India (IN)          Music            2006
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 502 entries, 0 to 1009
# Data columns (total 15 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Youtuber                                 502 non-null    object
#  1   Subscribers                              502 non-null    int64
#  2   Video views                              502 non-null    int64
#  3   Total Video count                        502 non-null    int64
#  4   Country                                  502 non-null    object
#  5   Category                                 502 non-null    object
#  6   Youtuber since                           502 non-null    int64
#  7   Last 7 Days Subscribers                  502 non-null    int64
#  8   Last 30 Days Subscribers                 502 non-null    int64
#  9   Last 90 Days Subscribers                 502 non-null    int64
# ...

# %%
df
# Out:
#                         Youtuber  Subscribers   Video views  \
# 0                        MrBeast    384000000   78500765091
# 1                       T-Series    292000000  293662998286
# 2     Cocomelon - Nursery Rhymes    192000000  199814715419
# 3                 YouTube Movies    188000000             0
# 4                      SET India    183000000  176535278856
# ...                          ...          ...           ...
# 1005               Lance Pugmire          337        786229
# 1006              vitaminwatermx          711        652261
# 1007                    Kim Dave       491000      34307156
# 1008         Arte da BÃª AteliÃª       469000      41911075
# 1009            sophia rodrigues        37500       2518780
#
#       Total Video count              Country       Category  Youtuber since  \
# 0                   859   United States (US)  Entertainment            2012
# 1                 23239           India (IN)          Music            2006
# ...

# %%
df.reset_index(drop=True,inplace=True)

# %%
df
# Out:
#                        Youtuber  Subscribers   Video views  Total Video count  \
# 0                       MrBeast    384000000   78500765091                859
# 1                      T-Series    292000000  293662998286              23239
# 2    Cocomelon - Nursery Rhymes    192000000  199814715419               1504
# 3                YouTube Movies    188000000             0                  0
# 4                     SET India    183000000  176535278856             153867
# ..                          ...          ...           ...                ...
# 497               Lance Pugmire          337        786229                177
# 498              vitaminwatermx          711        652261                 39
# 499                    Kim Dave       491000      34307156                652
# 500         Arte da BÃª AteliÃª       469000      41911075                518
# 501            sophia rodrigues        37500       2518780                181
#
# ...

# %%
df["Growth of Last 7 Days Video views"]=(df["Last 7 Days Video views"]/df["Video views"])*100
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6960\824238674.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Growth of Last 7 Days Video views"]=(df["Last 7 Days Video views"]/df["Video views"])*100

# %%
df["Growth of Last 30 Days Video views"]=(df["Last 30 Days Video views"]/df["Video views"])*100
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6960\595135860.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Growth of Last 30 Days Video views"]=(df["Last 30 Days Video views"]/df["Video views"])*100

# %%
df["Growth of Last 90 Days Video views"]=(df["Last 90 Days Video views"]/df["Video views"])*100
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6960\2461287315.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Growth of Last 90 Days Video views"]=(df["Last 90 Days Video views"]/df["Video views"])*100

# %%
df["Growth of Last 7 Days Subscribers"]=(df["Last 7 Days Subscribers"]/df["Subscribers"])*100
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6960\284144287.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Growth of Last 7 Days Subscribers"]=(df["Last 7 Days Subscribers"]/df["Subscribers"])*100

# %%
df["Growth of Last 30 Days Subscribers"]=(df["Last 30 Days Subscribers"]/df["Subscribers"])*100
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6960\1074064027.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Growth of Last 30 Days Subscribers"]=(df["Last 30 Days Subscribers"]/df["Subscribers"])*100

# %%
df["Growth of Last 90 Days Subscribers"]=(df["Last 90 Days Subscribers"]/df["Subscribers"])*100
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6960\1146947883.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Growth of Last 90 Days Subscribers"]=(df["Last 90 Days Subscribers"]/df["Subscribers"])*100

# %%
df["Growth of Last 7 Days Video views"]=df["Growth of Last 7 Days Video views"].fillna(0)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6960\1968339409.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Growth of Last 7 Days Video views"]=df["Growth of Last 7 Days Video views"].fillna(0)

# %%
df["Growth of Last 30 Days Video views"]=df["Growth of Last 30 Days Video views"].fillna(0)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6960\640515273.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Growth of Last 30 Days Video views"]=df["Growth of Last 30 Days Video views"].fillna(0)

# %%
df["Growth of Last 90 Days Video views"]=df["Growth of Last 90 Days Video views"].fillna(0)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6960\2948468576.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Growth of Last 90 Days Video views"]=df["Growth of Last 90 Days Video views"].fillna(0)

# %%
df
# Out:
#                        Youtuber  Subscribers   Video views  Total Video count  \
# 0                       MrBeast    384000000   78500765091                859
# 1                      T-Series    292000000  293662998286              23239
# 2    Cocomelon - Nursery Rhymes    192000000  199814715419               1504
# 3                YouTube Movies    188000000             0                  0
# 4                     SET India    183000000  176535278856             153867
# ..                          ...          ...           ...                ...
# 497               Lance Pugmire          337        786229                177
# 498              vitaminwatermx          711        652261                 39
# 499                    Kim Dave       491000      34307156                652
# 500         Arte da BÃª AteliÃª       469000      41911075                518
# 501            sophia rodrigues        37500       2518780                181
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 502 entries, 0 to 501
# Data columns (total 21 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Youtuber                                 502 non-null    object
#  1   Subscribers                              502 non-null    int64
#  2   Video views                              502 non-null    int64
#  3   Total Video count                        502 non-null    int64
#  4   Country                                  502 non-null    object
#  5   Category                                 502 non-null    object
#  6   Youtuber since                           502 non-null    int64
#  7   Last 7 Days Subscribers                  502 non-null    int64
#  8   Last 30 Days Subscribers                 502 non-null    int64
#  9   Last 90 Days Subscribers                 502 non-null    int64
# ...

# %%
df.to_csv("YT.csv",index=False)
